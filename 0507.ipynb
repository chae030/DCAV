# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris = iris.drop(labels='species', axis=1)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris_mean = iris.mean()
iris_mean
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
sns.barplot(x = iris_mean.index, y = iris_mean.values, palette='Set2')
# Out:
# /var/folders/bg/09yqnt111t34m8ws2pzns7yh0000gn/T/ipykernel_21840/2662125885.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = iris_mean.index, y = iris_mean.values, palette='Set2')
# <Axes: xlabel='None'>

# %%
df = pd.read_csv('gspc_data.csv')

# %%
df.head()
# Out:
#          Date        Close         High          Low         Open      Volume
# 0  2014-04-01  1885.520020  1885.839966  1873.959961  1873.959961  3336190000
# 1  2014-04-02  1890.900024  1893.170044  1883.790039  1886.609985  3131660000
# 2  2014-04-03  1888.770020  1893.800049  1882.650024  1891.430054  3055600000
# 3  2014-04-04  1865.089966  1897.280029  1863.260010  1890.250000  3583750000
# 4  2014-04-07  1845.040039  1864.040039  1841.479980  1863.920044  3801540000

# %%
df['Close'].plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(10,4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot.bar(stacked = True)
# Out:
# <Axes: >

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: >

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist(bins=15)
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'c'}>, <Axes: title={'center': 'd'}>]],
#       dtype=object)

# %%
iris.hist(bins=20, color = 'red')
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
iris.plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot(kind='hist', bins=50, stacked=True, orientation='horizontal')
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris['petal_width'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.hist(color='r', alpha=0.5) # alpha는 투명도
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
iris.diff().hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df = pd.read_csv('gspc_data.csv')
df = df.loc[df['Date'] >= '2020-01-01' , :]
df
# Out:
#             Date        Close         High          Low         Open  \
# 1449  2020-01-02  3257.850098  3258.139893  3235.530029  3244.669922
# 1450  2020-01-03  3234.850098  3246.149902  3222.340088  3226.360107
# 1451  2020-01-06  3246.280029  3246.840088  3214.639893  3217.550049
# 1452  2020-01-07  3237.179932  3244.909912  3232.429932  3241.860107
# 1453  2020-01-08  3253.050049  3267.070068  3236.669922  3238.590088
# ...          ...          ...          ...          ...          ...
# 2762  2025-03-25  5776.649902  5786.950195  5760.419922  5775.959961
# 2763  2025-03-26  5712.200195  5783.620117  5694.410156  5771.660156
# 2764  2025-03-27  5693.310059  5732.279785  5670.939941  5695.640137
# 2765  2025-03-28  5580.939941  5685.890137  5572.419922  5679.200195
# 2766  2025-03-31  5611.850098  5627.560059  5488.729980  5527.910156
#
#           Volume
# 1449  3459930000
# 1450  3484700000
# 1451  3702460000
# 1452  3435910000
# 1453  3726840000
# ...          ...
# ...

# %%
plt.plot(df['Close'])

# %%
df['Close'].plot(kind='hist', bins = 50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# yfinance 라이브러리를 사용하여 2020-01-01 부터 2025-04-30의 S&P500(^GSPC) 지수의 데이터를 다운로드하여 데이터프레임에서
# OHLC 가격의 boxplot 그리기
# OHLC 로그 수익률의 boxplot
# OHLC 20일 변동성  boxplot
