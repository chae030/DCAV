# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.regplot(x = 'sepal_length', y = 'petal_length', data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(iris['sepal_length'])
y = iris['petal_length']
model = sm.OLS(y , X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           petal_length   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     468.6
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):           1.04e-47
# Time:                        14:48:36   Log-Likelihood:                -190.57
# No. Observations:                 150   AIC:                             385.1
# Df Residuals:                     148   BIC:                             391.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# 회귀식 (2번 문제)
# y = -7.1014 + 1.8584*x
# petal_length = -7.1014 + 1.8584*sepal_length

# 3 
# 회귀계수 : 유의
# 회귀모형 : 유의

# 4
# 결정계수 (R-sqared) : 0.76으로 설명력이 있다고 볼 수 있다

# 5
# 회귀계수 : 1.86으로 p = b(베타) + 1.86s 이기 때문에 관계가 있다
# 즉 sepal_length가 한 단위(cm) 증가하면 petal_length는 약 1.86단위 증가한다.

# %%
# 잔차분석은 안함~~
