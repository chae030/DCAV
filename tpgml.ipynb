# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.common.keys import Keys
import pandas as pd

service = Service("/Users/parkchaeyeon/Desktop/GitHub/Data collection and visualization/chromedriver-mac-arm64/chromedriver")
driver = webdriver.Chrome(service = service)

# %%
keywords = ["여행", "화장품", "전기차"]
data = []

for keyword in keywords:
    for page in range(1, 4):
        url = f"https://section.blog.naver.com/Search/Post.naver?pageNo={page}&rangeType=ALL&orderBy=sim&keyword={keyword}"
        driver.get(url)
        time.sleep(1) 

        titles = driver.find_elements(By.CSS_SELECTOR, "span.title")
        authors = driver.find_elements(By.CSS_SELECTOR, "em.name_author")
        contents = driver.find_elements(By.CSS_SELECTOR, "div.desc > .text")

        for i in range(len(titles)):
            data.append({
                "Keyword": keyword,
                "Title": titles[i].text.strip(),
                "Author": authors[i].text.strip(),
                "Content": contents[i].text.strip()
            })
            
df = pd.DataFrame(data)
df
# Out:
#    Keyword                                       Title         Author  \
# 0       여행                         이탈리아 여행 동선 기간 지도 경비           Kimi
# 1       여행                          강릉 가족여행 숙소 세인트존스호텔             헤디
# 2       여행                           베트남 나트랑으로 떠난 가족여행           장미여사
# 3       여행                  11박 13일 스페인 포르투갈 여행 일정 공유!           트래블리
# 4       여행                      일본 규슈 소도시 온천 가족여행 리얼후기         베트남스토리
# ..     ...                                         ...            ...
# 58     전기차                     아이오닉6 장기렌트 전기차 보조금 받으세요  O1Oㅡ4756ㅡ3838
# 59     전기차                  전기차 가정용 충전기 7kw 편한 운행의 지름길            이종현
# 60     전기차             중국 주식 ETF 추천, 지수 기술주 전기차 뭘사야하지?        돈독한 스텔라
# 61     전기차  기아EV9 전기차 전용 한국 타이어 아이온 에보 AS 285 45 21 교환     tire party
# 62     전기차                        볼보 전기차 보조금 혜택 알고 계세요          디테일러명
#
#                                               Content
# 0   이탈리아 여행 동선 기간 지도 경비 후기 지금까지 유럽을 여러번 여행 하며 대부분 ...
# ...
